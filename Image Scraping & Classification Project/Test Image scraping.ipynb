# %%
#Importing required libraries

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

import selenium
from selenium import webdriver
import re
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time
from bs4 import BeautifulSoup

from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

import requests

# %%
#Connect to web driver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# Opening the Amazon.in
driver.get('https://www.flipkart.com/search?q=sarees&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off')

# %%
Saree_name = []
sareeimg_url=[]


for i in range(0,10):
    for j in driver.find_elements(By.XPATH, "//a[@class='IRpwTa']"):
        Saree_name.append(j.text)
    for j in driver.find_elements(By.XPATH, "//img[@class='_2r_T1I']"):
        sareeimg_url.append(j.get_attribute('src'))
        
    #Path for next page as it changes for every page. We are appending numbers as pages change 
    k=i+1
    next_page="https://www.flipkart.com/search?q=sarees&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"+str(k)
    driver.get(next_page)

# %%
# Checking the length of data extracted for sarees
print(len(sareeimg_url))
# Out:
# 400

# %%
for i in range(len(sareeimg_url)):

    if i >= 100:

        break

    print("Downloading {0} of {1} images" .format(i, 100))

    response= requests.get(sareeimg_url[i])

    file = open(r"D:\Images\Test\Sarees\saree"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
# Getting the website to driver
driver.get('https://www.amazon.in/s?k=amazon+jeans+for+men&page=6&hvadid=72224283643800&hvbmt=be&hvdev=c&hvqmt=e&qid=1668237326&ref=sr_pg_6')

# %%
Jeans_name = []
jeansimg_url=[]


for i in range(0,2):
    for j in driver.find_elements(By.XPATH, "//span[@class='a-size-base-plus a-color-base a-text-normal']"):
        Jeans_name.append(j.text)
    for j in driver.find_elements(By.XPATH, "//img[@class='s-image']"):
        jeansimg_url.append(j.get_attribute('src'))
    
    #Path for next page as it changes for every page. We are appending numbers as pages change 

    k=i+1
    next_page="https://www.amazon.in/s?k=amazon+jeans+for+men&page=6&hvadid=72224283643800&hvbmt=be&hvdev=c&hvqmt=e&qid=1668237326&ref=sr_pg_6"+str(k)
    driver.get(next_page)

# %%
# Checking the length of data extracted for jeans
print(len(jeansimg_url))
# Out:
# 120

# %%
for i in range(len(jeansimg_url)):

    if i >= 100:

        break

    print("Downloading {0} of {1} images" .format(i, 100))

    response= requests.get(jeansimg_url[i])

    file = open(r"D:\Images\Test\Jeans\jeans"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
# Getting the website to driver
driver.get('https://www.amazon.in/s?k=trouser+for+men&page=6&crid=1WLKF8MPOER9J&qid=1668237771&sprefix=trouser+for+men%2Caps%2C512&ref=sr_pg_6')

# %%
Trouser_name = []
trouserimg_url=[]


for i in range(0,3):
    for j in driver.find_elements(By.XPATH, "//span[@class='a-size-base-plus a-color-base a-text-normal']"):
        Trouser_name.append(j.text)
    for j in driver.find_elements(By.XPATH, "//img[@class='s-image']"):
        trouserimg_url.append(j.get_attribute('src'))
    
    
    #Path for next page as it changes for every page. We are appending numbers as pages change 
    k=i+1
    next_page="https://www.amazon.in/s?k=trouser+for+men&page=6&crid=1WLKF8MPOER9J&qid=1668237771&sprefix=trouser+for+men%2Caps%2C512&ref=sr_pg_6"+str(k)
    driver.get(next_page)

# %%
# Checking the length of data extracted for sarees
print(len(trouserimg_url))
# Out:
# 168

# %%
for i in range(len(trouserimg_url)):

    if i >= 100:

        break

    print("Downloading {0} of {1} images" .format(i, 100))

    response= requests.get(trouserimg_url[i])

    file = open(r"D:\Images\Test\Trousers\trouser"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
Product_Name=(Saree_name[:100]+Jeans_name[:100]+Trouser_name[:100])
IMG_URL=(sareeimg_url[:100]+jeansimg_url[:100]+trouserimg_url[:100])

# %%
#Saving in dataframe
Imagestest_df=pd.DataFrame({'Product_Name':Product_Name,'Image_URL':IMG_URL})

# %%
Imagestest_df
# Out:
#                                           Product_Name  \
# 0              Embroidered Bollywood Lycra Blend Saree
# 1                Color Block Bollywood Georgette Saree
# 2                Embellished Bollywood Georgette Saree
# 3                     Printed Bandhani Georgette Saree
# 4                Embellished Bollywood Georgette Saree
# ..                                                 ...
# 295  Solid Men's Formal Pleated Front Trouser Regul...
# 296                            Men's Slim Casual Pants
# 297  Men's Slim Fit Trousers (Atlanta_Satin_GRENISH...
# 298                                   Men Casual Pants
# 299                                      Grey Trousers
#
#                                              Image_URL
# 0    https://rukminim1.flixcart.com/image/329/395/k...
# 1    https://rukminim1.flixcart.com/image/329/395/k...
# 2    https://rukminim1.flixcart.com/image/329/395/k...
# 3    https://rukminim1.flixcart.com/image/329/395/x...
# 4    https://rukminim1.flixcart.com/image/329/395/k...
# ..                                                 ...
# 295  https://m.media-amazon.com/images/I/71OPlt5KBF...
# 296  https://m.media-amazon.com/images/I/61euIulaBC...
# 297  https://m.media-amazon.com/images/I/91a9nyCI9I...
# 298  https://m.media-amazon.com/images/I/61WyD+al28...
# 299  https://m.media-amazon.com/images/I/61q2Nw6Ynh...
#
# [300 rows x 2 columns]

# %%
driver.close()

# %%
# Saving the data into a csv file
Imagestest_df.to_csv('Imagestest_dataset.csv')
